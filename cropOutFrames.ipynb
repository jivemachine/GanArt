# %% [markdown]
# # this file crops the scraped images

# %%
import numpy as np
from PIL import Image 
from matplotlib.pyplot import figure
from os import listdir
from scipy.spatial import distance

# %%
from_path = 'art/wikiart/'
to_path   = 'art/cropped/'

# %%
def find_left():
    left = 0
    for i in range(0, w_pad):
        r_stdev = np.std(np_img[h_pad:-h_pad,i:i+1,0:1])
        g_stdev = np.std(np_img[h_pad:-h_pad,i:i+1,1:2])
        b_stdev = np.std(np_img[h_pad:-h_pad,i:i+1,2:3])
        if r_stdev*r_stdev+g_stdev*g_stdev+b_stdev*b_stdev > thresh1:
            break

        r_med = np.median(np_img[h_pad:-h_pad,i:i+1,0:1])
        g_med = np.median(np_img[h_pad:-h_pad,i:i+1,1:2])
        b_med = np.median(np_img[h_pad:-h_pad,i:i+1,2:3])
        dst = distance.euclidean((r_med, g_med, b_med), (r_global_med, g_global_med, b_global_med))
        if dst < thresh2:
            break

        left = left+1
    return left

# %%
def find_top():
    top = 0
    for i in range(0, h_pad):
        r_stdev = np.std(np_img[i:i+1,w_pad:-w_pad,0:1])
        g_stdev = np.std(np_img[i:i+1,w_pad:-w_pad,1:2])
        b_stdev = np.std(np_img[i:i+1,w_pad:-w_pad,2:3])
        if r_stdev*r_stdev+g_stdev*g_stdev+b_stdev*b_stdev > thresh1:
            break

        r_med = np.median(np_img[i:i+1,w_pad:-w_pad,0:1])
        g_med = np.median(np_img[i:i+1,w_pad:-w_pad,1:2])
        b_med = np.median(np_img[i:i+1,w_pad:-w_pad,2:3])
        dst = distance.euclidean((r_med, g_med, b_med), (r_global_med, g_global_med, b_global_med))
        if dst < thresh2:
            break

        top = top+1
    return top

# %%
def find_right(right):
    right = w
    for i in range(0, w_pad):
        r_stdev = np.std(np_img[h_pad:-h_pad,w-i-1:w-i,0:1])
        g_stdev = np.std(np_img[h_pad:-h_pad,w-i-1:w-i,1:2])
        b_stdev = np.std(np_img[h_pad:-h_pad,w-i-1:w-i,2:3])
        if r_stdev*r_stdev+g_stdev*g_stdev+b_stdev*b_stdev > thresh1:
            break

        r_med = np.median(np_img[h_pad:-h_pad,w-i-1:w-i,0:1])
        g_med = np.median(np_img[h_pad:-h_pad,w-i-1:w-i,1:2])
        b_med = np.median(np_img[h_pad:-h_pad,w-i-1:w-i,2:3])
        dst = distance.euclidean((r_med, g_med, b_med), (r_global_med, g_global_med, b_global_med))
        if dst < thresh2:
            break

        right = right-1
    return right

# %%
def find_bottom(bottom):
    for i in range(0, h_pad):
        r_stdev = np.std(np_img[h-i-1:h-i,w_pad:-w_pad,0:1])
        g_stdev = np.std(np_img[h-i-1:h-i,w_pad:-w_pad,1:2])
        b_stdev = np.std(np_img[h-i-1:h-i,w_pad:-w_pad,2:3])
        if r_stdev*r_stdev+g_stdev*g_stdev+b_stdev*b_stdev > thresh1:
            break

        r_med = np.median(np_img[h-i-1:h-i,w_pad:-w_pad,0:1])
        g_med = np.median(np_img[h-i-1:h-i,w_pad:-w_pad,1:2])
        b_med = np.median(np_img[h-i-1:h-i,w_pad:-w_pad,2:3])
        dst = distance.euclidean((r_med, g_med, b_med), (r_global_med, g_global_med, b_global_med))
        if dst < thresh2:
            break

        bottom = bottom-1
    return bottom

# %%
for file in listdir(from_path):

    img = Image.open(from_path + '/' + file)
    print(file)

    np_img = np.asarray(img)
    print("shape = " + str(np_img.shape))

    thresh1 = 15000
    thresh2 = 30
    w = img.width
    h = img.height
    pad = 30
    w_pad = w//pad
    h_pad = h//pad

    r_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,0:1])
    g_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,1:2])
    b_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,2:3])

    left = find_left()
    top = find_top()
    right = find_right(w)
    bottom = find_bottom(h)

    print("left = " + str(left) + ", top = " + str(top) +
        ", right = " + str(right) +  ", bottom = " + str(bottom) + "\n")

    img.save(to_path  + file)                                   # save the original
    cropped_img = img.crop((left, top, right, bottom))
    cropped_img.save(to_path  + file[:-4] + "_cropped.jpg")     # and the cropped version
# Out:
# olga-rozanova_5.jpg
# shape = (825, 759, 3)
# left = 25, top = 27, right = 734, bottom = 798
#
# alexej-von-jawlensky_5.jpg
# shape = (768, 571, 3)
# left = 2, top = 25, right = 552, bottom = 768
#
# georgia-o-keeffe_3.jpg
# shape = (1779, 1318, 3)
# left = 43, top = 0, right = 1293, bottom = 1779
#
# theo-van-doesburg_54.jpg
# shape = (2868, 2825, 3)
# left = 59, top = 0, right = 2731, bottom = 2773
#
# oleksandr-bogomazov_6.jpg
# shape = (516, 600, 3)
# left = 0, top = 0, right = 580, bottom = 513
#
# fernand-leger_3.jpg
# shape = (635, 758, 3)
# left = 0, top = 0, right = 758, bottom = 635
#
# georgia-o-keeffe_10.jpg
# shape = (600, 500, 3)
# left = 16, top = 20, right = 484, bottom = 600
#
# kurt-schwitters_5.jpg
# shape = (1078, 795, 3)
# left = 11, top = 9, right = 779, bottom = 1065
#
# theo-van-doesburg_40.jpg
# shape = (802, 406, 3)
# left = 0, top = 0, right = 406, bottom = 802
#
# hilma-af-klint_4.jpg
# shape = (590, 447, 3)
# left = 13, top = 11, right = 433, bottom = 576
#
# joaquin-torres-garcia_13.jpg
# shape = (600, 600, 3)
# left = 20, top = 20, right = 600, bottom = 580
#
# aleksandra-ekster_0.jpg
# shape = (400, 388, 3)
# left = 12, top = 13, right = 376, bottom = 387
#
# frantisek-kupka_4.jpg
# shape = (671, 622, 3)
# left = 3, top = 22, right = 602, bottom = 649
#
# erich-buchholz_11.jpg
# shape = (886, 750, 3)
# left = 8, top = 0, right = 725, bottom = 857
#
# otto-freundlich_3.jpg
# shape = (750, 489, 3)
# left = 16, top = 22, right = 473, bottom = 725
#
# mikhail-larionov_2.jpg
# shape = (1253, 1536, 3)
# left = 13, top = 0, right = 1485, bottom = 1247
#
# fernand-leger_14.jpg
# shape = (2064, 1686, 3)
# left = 10, top = 0, right = 1663, bottom = 2006
#
# marsden-hartley_3.jpg
# shape = (501, 500, 3)
# left = 16, top = 16, right = 500, bottom = 499
#
# arthur-dove_0.jpg
# shape = (1024, 1228, 3)
# left = 40, top = 18, right = 1217, bottom = 1018
#
# piet-mondrian_8.jpg
# shape = (1133, 700, 3)
# left = 0, top = 37, right = 700, bottom = 1133
#
# wassily-kandinsky_64.jpg
# shape = (1235, 1000, 3)
# left = 0, top = 0, right = 1000, bottom = 1235
#
# wassily-kandinsky_70.jpg
# shape = (531, 450, 3)
# left = 0, top = 1, right = 450, bottom = 531
#
# joseph-stella_1.jpg
# shape = (1696, 1297, 3)
# left = 1, top = 56, right = 1254, bottom = 1640
#
# wassily-kandinsky_58.jpg
# shape = (650, 757, 3)
# left = 0, top = 0, right = 757, bottom = 650
#
# el-lissitzky_1.jpg
# shape = (1057, 1417, 3)
# left = 47, top = 35, right = 1370, bottom = 1022
#
# wyndham-lewis_0.jpg
# shape = (1536, 1206, 3)
# left = 29, top = 38, right = 1184, bottom = 1515
#
# giacomo-balla_33.jpg
# shape = (359, 500, 3)
# left = 8, top = 2, right = 491, bottom = 348
#
# wassily-kandinsky_127.jpg
# shape = (800, 526, 3)
# left = 0, top = 0, right = 526, bottom = 774
#
# theo-van-doesburg_0.jpg
# shape = (1090, 768, 3)
# left = 0, top = 0, right = 768, bottom = 1090
#
# wassily-kandinsky_133.jpg
# shape = (1413, 1800, 3)
# left = 60, top = 1, right = 1800, bottom = 1412
#
# giacomo-balla_27.jpg
# shape = (1105, 1395, 3)
# left = 0, top = 0, right = 1395, bottom = 1069
#
# jean-hugo_0.jpg
# shape = (400, 290, 3)
# left = 0, top = 0, right = 290, bottom = 400
#
# kazimir-malevich_12.jpg
# shape = (999, 1000, 3)
# left = 0, top = 0, right = 1000, bottom = 966
#
# hannah-hoch_0.jpg
# shape = (448, 350, 3)
# left = 0, top = 2, right = 350, bottom = 448
#
# paul-klee_49.jpg
# shape = (758, 579, 3)
# left = 0, top = 0, right = 575, bottom = 758
#
# paul-klee_48.jpg
# shape = (1111, 790, 3)
# left = 0, top = 0, right = 790, bottom = 1111
#
# leopold-survage_0.jpg
# shape = (420, 313, 3)
# left = 0, top = 0, right = 313, bottom = 420
#
# kazimir-malevich_13.jpg
# shape = (1000, 750, 3)
# left = 25, top = 33, right = 725, bottom = 967
#
# wassily-kandinsky_132.jpg
# shape = (650, 654, 3)
# left = 6, top = 6, right = 648, bottom = 647
#
# giacomo-balla_26.jpg
# shape = (600, 636, 3)
# left = 21, top = 20, right = 615, bottom = 580
#
# paul-klee_60.jpg
# shape = (4000, 2766, 3)
# left = 92, top = 133, right = 2674, bottom = 3885
#
# giacomo-balla_32.jpg
# shape = (586, 790, 3)
# left = 0, top = 19, right = 790, bottom = 568
#
# wyndham-lewis_1.jpg
# shape = (1274, 1536, 3)
# left = 51, top = 42, right = 1485, bottom = 1232
#
# theo-van-doesburg_1.jpg
# shape = (1126, 768, 3)
# left = 4, top = 1, right = 768, bottom = 1125
#
# wassily-kandinsky_126.jpg
# shape = (1387, 1800, 3)
# left = 60, top = 6, right = 1740, bottom = 1384
#
# el-lissitzky_0.jpg
# shape = (700, 524, 3)
# left = 0, top = 3, right = 524, bottom = 698
#
# wassily-kandinsky_59.jpg
# shape = (811, 1063, 3)
# left = 19, top = 24, right = 1042, bottom = 789
#
# joseph-stella_0.jpg
# shape = (1078, 1428, 3)
# left = 47, top = 0, right = 1381, bottom = 1078
#
# wassily-kandinsky_71.jpg
# shape = (532, 450, 3)
# left = 15, top = 17, right = 435, bottom = 532
#
# wassily-kandinsky_65.jpg
# shape = (750, 587, 3)
# left = 0, top = 0, right = 587, bottom = 750
#
# piet-mondrian_9.jpg
# shape = (800, 653, 3)
# left = 6, top = 26, right = 653, bottom = 800
#
# arthur-dove_1.jpg
# shape = (535, 450, 3)
# left = 15, top = 0, right = 450, bottom = 535
#
# marsden-hartley_2.jpg
# shape = (2401, 2040, 3)
# left = 31, top = 0, right = 1972, bottom = 2321
#
# jock-macdonald_8.jpg
# shape = (575, 514, 3)
# left = 1, top = 2, right = 497, bottom = 556
#
# fernand-leger_15.jpg
# shape = (2070, 1656, 3)
# left = 0, top = 0, right = 1656, bottom = 2069
#
# otto-freundlich_2.jpg
# shape = (808, 570, 3)
# left = 19, top = 13, right = 570, bottom = 808
#
# erich-buchholz_10.jpg
# shape = (570, 426, 3)
# left = 14, top = 19, right = 412, bottom = 555
#
# joaquin-torres-garcia_12.jpg
# shape = (600, 567, 3)
# left = 0, top = 0, right = 567, bottom = 600
#
# frantisek-kupka_5.jpg
# shape = (450, 481, 3)
# left = 16, top = 15, right = 465, bottom = 435
#
# aleksandra-ekster_1.jpg
# shape = (484, 400, 3)
# left = 13, top = 16, right = 387, bottom = 468
#
# hilma-af-klint_5.jpg
# shape = (1280, 1278, 3)
# left = 0, top = 0, right = 1278, bottom = 1280
#
# georgia-o-keeffe_11.jpg
# shape = (967, 768, 3)
# left = 1, top = 32, right = 764, bottom = 935
#
# fernand-leger_2.jpg
# shape = (2484, 1980, 3)
# left = 52, top = 18, right = 1980, bottom = 2402
#
# theo-van-doesburg_41.jpg
# shape = (2544, 4629, 3)
# left = 56, top = 23, right = 4618, bottom = 2519
#
# kurt-schwitters_4.jpg
# shape = (1050, 824, 3)
# left = 1, top = 35, right = 797, bottom = 1043
#
# theo-van-doesburg_55.jpg
# shape = (1596, 1200, 3)
# left = 40, top = 53, right = 1160, bottom = 1543
#
# alexej-von-jawlensky_4.jpg
# shape = (1142, 842, 3)
# left = 9, top = 19, right = 827, bottom = 1142
#
# georgia-o-keeffe_2.jpg
# shape = (706, 564, 3)
# left = 0, top = 1, right = 564, bottom = 698
#
# olga-rozanova_4.jpg
# shape = (900, 759, 3)
# left = 25, top = 30, right = 747, bottom = 900
#
# giacomo-balla_9.jpg
# shape = (1200, 1600, 3)
# left = 53, top = 40, right = 1547, bottom = 1161
#
# olga-rozanova_6.jpg
# shape = (565, 805, 3)
# left = 0, top = 0, right = 805, bottom = 565
#
# georgia-o-keeffe_0.jpg
# shape = (1500, 1178, 3)
# left = 0, top = 0, right = 1178, bottom = 1500
#
# alexej-von-jawlensky_6.jpg
# shape = (1024, 772, 3)
# left = 17, top = 34, right = 757, bottom = 990
#
# kurt-schwitters_6.jpg
# shape = (1035, 788, 3)
# left = 18, top = 23, right = 762, bottom = 1001
#
# theo-van-doesburg_43.jpg
# shape = (490, 477, 3)
# left = 15, top = 16, right = 475, bottom = 474
#
# jacoba-van-heemskerck_8.jpg
# shape = (418, 512, 3)
# left = 0, top = 10, right = 511, bottom = 417
#
# fernand-leger_0.jpg
# shape = (2478, 2106, 3)
# left = 0, top = 0, right = 2036, bottom = 2416
#
# georgia-o-keeffe_13.jpg
# shape = (1280, 858, 3)
# left = 0, top = 42, right = 830, bottom = 1238
#
# oleksandr-bogomazov_5.jpg
# shape = (851, 714, 3)
# left = 22, top = 28, right = 701, bottom = 829
#
# theo-van-doesburg_57.jpg
# shape = (883, 1200, 3)
# left = 40, top = 29, right = 1160, bottom = 854
#
# hilma-af-klint_7.jpg
# shape = (474, 462, 3)
# left = 0, top = 0, right = 461, bottom = 474
#
# erich-buchholz_12.jpg
# shape = (509, 400, 3)
# left = 13, top = 16, right = 387, bottom = 493
#
# aleksandra-ekster_3.jpg
# shape = (450, 316, 3)
# left = 1, top = 9, right = 306, bottom = 435
#
# frantisek-kupka_7.jpg
# shape = (1260, 2000, 3)
# left = 0, top = 0, right = 2000, bottom = 1260
#
# joaquin-torres-garcia_10.jpg
# shape = (363, 256, 3)
# left = 8, top = 5, right = 256, bottom = 358
#
# fernand-leger_17.jpg
# shape = (2484, 1961, 3)
# left = 23, top = 0, right = 1960, bottom = 2483
#
# robert-delaunay_9.jpg
# shape = (1087, 1080, 3)
# left = 1, top = 36, right = 1080, bottom = 1087
#
# mikhail-larionov_1.jpg
# shape = (4096, 3812, 3)
# left = 0, top = 5, right = 3812, bottom = 4077
#
# otto-freundlich_0.jpg
# shape = (639, 500, 3)
# left = 16, top = 5, right = 500, bottom = 639
#
# marsden-hartley_0.jpg
# shape = (432, 357, 3)
# left = 3, top = 0, right = 351, bottom = 424
#
# arthur-dove_3.jpg
# shape = (482, 650, 3)
# left = 0, top = 16, right = 648, bottom = 472
#
# wassily-kandinsky_73.jpg
# shape = (536, 711, 3)
# left = 23, top = 17, right = 709, bottom = 519
#
# joseph-stella_2.jpg
# shape = (1338, 1434, 3)
# left = 47, top = 44, right = 1434, bottom = 1294
#
# wassily-kandinsky_67.jpg
# shape = (680, 580, 3)
# left = 0, top = 0, right = 580, bottom = 680
#
# el-lissitzky_2.jpg
# shape = (1600, 967, 3)
# left = 2, top = 0, right = 967, bottom = 1598
#
# giacomo-balla_24.jpg
# shape = (1188, 1578, 3)
# left = 52, top = 0, right = 1574, bottom = 1149
#
# kazimir-malevich_39.jpg
# shape = (1867, 2289, 3)
# left = 39, top = 26, right = 2254, bottom = 1833
#
# wassily-kandinsky_130.jpg
# shape = (533, 800, 3)
# left = 0, top = 0, right = 800, bottom = 516
#
# gosta-adrian-nilsson_0.jpg
# shape = (500, 397, 3)
# left = 13, top = 16, right = 393, bottom = 484
#
# wassily-kandinsky_124.jpg
# shape = (713, 1063, 3)
# left = 19, top = 21, right = 1043, bottom = 693
#
# theo-van-doesburg_3.jpg
# shape = (1274, 1199, 3)
# left = 5, top = 23, right = 1194, bottom = 1232
#
# giacomo-balla_30.jpg
# shape = (386, 500, 3)
# left = 3, top = 12, right = 484, bottom = 374
#
# giacomo-balla_18.jpg
# shape = (800, 610, 3)
# left = 1, top = 26, right = 609, bottom = 774
#
# wassily-kandinsky_118.jpg
# shape = (650, 509, 3)
# left = 3, top = 3, right = 506, bottom = 647
#
# kazimir-malevich_11.jpg
# shape = (688, 533, 3)
# left = 0, top = 22, right = 532, bottom = 688
#
# wassily-kandinsky_98.jpg
# shape = (1481, 1063, 3)
# left = 19, top = 49, right = 1028, bottom = 1461
#
# wassily-kandinsky_119.jpg
# shape = (1466, 1800, 3)
# left = 0, top = 0, right = 1799, bottom = 1464
#
# wassily-kandinsky_99.jpg
# shape = (800, 554, 3)
# left = 0, top = 0, right = 554, bottom = 800
#
# kazimir-malevich_10.jpg
# shape = (739, 600, 3)
# left = 0, top = 2, right = 600, bottom = 723
#
# giacomo-balla_19.jpg
# shape = (1187, 1397, 3)
# left = 11, top = 39, right = 1351, bottom = 1185
#
# theo-van-doesburg_2.jpg
# shape = (1749, 1189, 3)
# left = 0, top = 0, right = 1189, bottom = 1749
#
# wassily-kandinsky_125.jpg
# shape = (774, 575, 3)
# left = 0, top = 0, right = 566, bottom = 749
#
# giacomo-balla_31.jpg
# shape = (1200, 939, 3)
# left = 25, top = 3, right = 908, bottom = 1160
#
# wyndham-lewis_2.jpg
# shape = (1148, 528, 3)
# left = 0, top = 8, right = 528, bottom = 1110
#
# kazimir-malevich_38.jpg
# shape = (1863, 2306, 3)
# left = 44, top = 31, right = 2257, bottom = 1838
#
# giacomo-balla_25.jpg
# shape = (1431, 1412, 3)
# left = 47, top = 8, right = 1412, bottom = 1431
#
# wassily-kandinsky_131.jpg
# shape = (1601, 790, 3)
# left = 10, top = 0, right = 764, bottom = 1584
#
# f-lix-del-marle_0.jpg
# shape = (420, 320, 3)
# left = 10, top = 0, right = 310, bottom = 420
#
# wassily-kandinsky_66.jpg
# shape = (722, 565, 3)
# left = 12, top = 24, right = 557, bottom = 698
#
# joseph-stella_3.jpg
# shape = (1181, 1437, 3)
# left = 47, top = 33, right = 1390, bottom = 1142
#
# wassily-kandinsky_72.jpg
# shape = (891, 1280, 3)
# left = 0, top = 0, right = 1280, bottom = 891
#
# arthur-dove_2.jpg
# shape = (1025, 1500, 3)
# left = 1, top = 34, right = 1498, bottom = 991
#
# marsden-hartley_1.jpg
# shape = (768, 762, 3)
# left = 13, top = 25, right = 746, bottom = 743
#
# robert-delaunay_8.jpg
# shape = (488, 540, 3)
# left = 18, top = 16, right = 522, bottom = 472
#
# mikhail-larionov_0.jpg
# shape = (899, 1181, 3)
# left = 39, top = 29, right = 1142, bottom = 894
#
# otto-freundlich_1.jpg
# shape = (824, 570, 3)
# left = 0, top = 27, right = 551, bottom = 808
#
# fernand-leger_16.jpg
# shape = (2070, 1698, 3)
# left = 10, top = 0, right = 1697, bottom = 2070
#
# frantisek-kupka_6.jpg
# shape = (2091, 2056, 3)
# left = 58, top = 69, right = 1988, bottom = 2022
#
# aleksandra-ekster_2.jpg
# shape = (1006, 769, 3)
# left = 25, top = 33, right = 744, bottom = 1002
#
# joaquin-torres-garcia_11.jpg
# shape = (648, 974, 3)
# left = 8, top = 10, right = 970, bottom = 648
#
# erich-buchholz_13.jpg
# shape = (400, 600, 3)
# left = 14, top = 13, right = 580, bottom = 387
#
# hilma-af-klint_6.jpg
# shape = (481, 364, 3)
# left = 12, top = 2, right = 352, bottom = 465
#
# oleksandr-bogomazov_4.jpg
# shape = (1756, 1846, 3)
# left = 61, top = 58, right = 1785, bottom = 1756
#
# theo-van-doesburg_56.jpg
# shape = (1715, 1200, 3)
# left = 0, top = 0, right = 1160, bottom = 1715
#
# theo-van-doesburg_42.jpg
# shape = (3320, 3328, 3)
# left = 0, top = 2, right = 3326, bottom = 3320
#
# kurt-schwitters_7.jpg
# shape = (1124, 752, 3)
# left = 1, top = 37, right = 751, bottom = 1123
#
# georgia-o-keeffe_12.jpg
# shape = (500, 397, 3)
# left = 13, top = 16, right = 384, bottom = 498
#
# fernand-leger_1.jpg
# shape = (2364, 1884, 3)
# left = 0, top = 33, right = 1884, bottom = 2362
#
# georgia-o-keeffe_1.jpg
# shape = ()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-7b6b929d4214> in <module>()
#      15     h_pad = h//pad
#      16
# ---> 17     r_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,0:1])
#      18     g_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,1:2])
#      19     b_global_med = np.median(np_img[h_pad:-h_pad,w_pad:-w_pad,2:3])
#
# IndexError: too many indices for array
